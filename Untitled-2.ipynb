# %%
import numpy as np
from scipy.optimize import approx_fprime
import matplotlib.pyplot as plt
#from antidifferentiation import gradient
#test ewfsdfd dsf

# %% [markdown]
# #PS5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# let $f(x_i)$ be the Rosenbrock function defined above. The lagrangian is:
#
# $$ \mathcal{L}(x_{i}, \lambda) = f(x_{i}) - \lambda ( \sum_{i=1}^{n} x_{i}^{2} - r)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#first we define the rosenbrock function with unknown parameters a and b 
def rosenbrock(x,a = 1,b = 1):
    return sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 )


#lagrangian
def lagrangian(x, lamda = 0.5, r=2): #output should be a 1 dimensional scalar value 
    return rosenbrock(x) - lamda * (np.sum(x**2) - r)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#  The first n elements of the array correspond to the gradient of the Lagrangian with respect to the x variables, and the last element corresponds to the gradient with respect to the lambda variable.
#
#
# The gradient with respect to the x variables is calculated by taking the derivative of the Lagrangian with respect to each x_i and summing the results. The gradient with respect to lambda is simply the sum of the squares of the x variables minus the value of the constraint r.

# %%
# def lagrangian_gradient_func(x, λ, r=4):
#     ''' inputs a function then, outputs a new function that calculates the gradient of the lagrangian'''
#     return gradient(lambda x: lagrangian(x, λ, r))(x)

#manual method

# def lagrangian_gradient_func(x, lamda = 0.5, r = 2, a=1 , b=1): #this calculates the true gradient(not approximation)

#     n = len(x)
#     gradient_x = np.zeros(n)
#     for i in range(n - 1):
#         gradient_x[i] = 2 * (1 - x[i]) * a - 2 * b * (x[i+1] - x[i]**2) * 2 * x[i]
#         gradient_x[i+1] = 2 * b * (x[i+1] - x[i]**2)
#     gradient_x = gradient_x - 2 * lamda * x
#     gradient_lambda = np.sum(x**2) - r
#     return np.concatenate((gradient_x, [gradient_lambda]))


def lagrangian_gradient_func(x, lamda = 0.5, r = 2, a=1 , b=1): #this calculates the true gradient(not approximation)

    n = len(x)
    gradient_x = np.zeros(n)
    for i in range(n - 1):
        gradient_x[i] = 2 * (1 - x[i]) * a - 2 * b * (x[i+1] - x[i]**2) * 2 * x[i]
        gradient_x[i+1] = 2 * b * (x[i+1] - x[i]**2)
    gradient_x = gradient_x - 2 * lamda * x
    #gradient_lambda = np.sum(x**2) - r #might wanna remove this ask albert or jacob 
    return (gradient_x)


#testcase
x = np.array([1, 2])
lamda = 0.5
r = 2

gradient = lagrangian_gradient_func(x, lamda, r)
print(gradient)
# Out:
# [-5.  0.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 5 #dimension of the vector /initial x
r = 2 # from the constraint

#first we define a first differencing function 
# def finite_difference_gradient(x, lamda = 0.5, h = 1e-6):
#     n = len(x)
#     gradient_x = np.zeros(n)
#     for i in range(n):
#         x_plus = x.copy()
#         x_plus[i] += h
#         x_minus = x.copy()
#         x_minus[i] -= h
#         gradient_x[i] = (lagrangian(x_plus, lamda, r) - lagrangian(x_minus, lamda, r)) / (2 * h)
#     lamda_plus = lamda + h
#     lamda_minus = lamda - h
#     gradient_lambda = (lagrangian(x, lamda_plus, r) - lagrangian(x, lamda_minus, r)) / (2 * h)
#     return np.concatenate((gradient_x, [gradient_lambda]))

def finite_difference_gradient(x, lamda = 0.5, h = 1e-6):
    n = len(x)
    gradient_x = np.zeros(n)
    for i in range(n):
        x_plus = x.copy()
        x_plus[i] += h
        x_minus = x.copy()
        x_minus[i] -= h
        gradient_x[i] = (lagrangian(x_plus, lamda, r) - lagrangian(x_minus, lamda, r)) / (2 * h)
    lamda_plus = lamda + h
    lamda_minus = lamda - h
    gradient_lambda = (lagrangian(x, lamda_plus, r) - lagrangian(x, lamda_minus, r)) / (2 * h)
    return gradient_x

#we could also use scipy.optimize import approx_fprime to find the gradient.


x = np.random.rand(n)
finite_difference = np.array([approx_fprime(x, lagrangian, epsilon=1e-6)])
print(finite_difference)
# print(finite_difference_gradient(x, lamda=0.5))
#loop to investigate rmse 
num_samples = 100
error = 0
for i in range(num_samples):
    x = np.random.rand(n) #  generates an array  n numbers from a uniform distribution over  [0, 1]
    lamda = np.random.rand() #the 6th uniform number
    true_gradient = np.array(lagrangian_gradient_func(x, lamda, r=4))
    finite_diff_gradient = np.array(approx_fprime(x, lagrangian, epsilon=1e-6))
    error += np.sum((np.abs(true_gradient - finite_diff_gradient))**2)
error = np.sqrt(error / num_samples)
print("Root mean squared error:", error)
# Out:
# [[ 0.88201803 -0.65220001  1.99748182 -2.44100027 -0.36010182]]
# Root mean squared error: 4.962698583298161

# %% [markdown]
# ![image.png](attachment:image.png)
#
# In this code, the hessian_DL function calculates the Hessian of the Lagrangian as a function of the point x and the multiplier lamda. The function returns the Hessian as a 2D numpy array, with shape (n+1, n+1), where n is the number of variables in x. The Hessian is calculated using the analytical expression for the second derivatives of the Lagrangian with respect to x and lambda. The resulting Hessian matrix is stored in the variable hessian_DL.

# %%
def lagrangian_hessian_func(x, lamda = 0.5, r = 2, a=1 , b=1):
    n = len(x)
    hessian = np.zeros((n, n))
    for i in range(n - 1):
        hessian[i, i] = 2 * a + 8 * b * x[i]**2
        hessian[i, i+1] = -4 * b * x[i]
        hessian[i+1, i] = -4 * b * x[i]
        hessian[i+1, i+1] = 2 * b
    hessian = hessian - 2 * lamda * np.eye(n)
    return hessian

a = 1
b = 1
x = np.array([0,0])
lamda = 0.5
hessian = lagrangian_hessian_func(x, lamda = 0.5)
print(hessian)

rank = np.linalg.matrix_rank(hessian)
if rank == hessian.shape[1]:
    print("Matrix is invertible.")
else:
    print("Matrix is not invertible.")
# Out:
# [[1. 0.]
#  [0. 1.]]
# Matrix is invertible.

# %%
# def hessian_DL(x, lamda = 0.5, r=2):
#     n = len(x)
#     hessian_x = np.zeros((n, n))
#     a = 1
#     b = 1
#     for i in range(n - 1):
#         hessian_x[i, i] = 2 * a + 2 * b * 2 * x[i]**2 - 4 * b * (x[i+1] - x[i]**2)
#         hessian_x[i+1, i] = -4 * b * x[i]
#         hessian_x[i, i+1] = -4 * b * x[i]
#         hessian_x[i+1, i+1] = 2 * b
#     hessian_x = hessian_x - 2 * np.eye(n) * lamda
#     hessian_lambda = np.zeros((1, 1))
#     hessian_lambda[0, 0] = np.sum(2 * x)
#     hessian_xlambda = np.zeros((n, 1))
#     hessian_lambda_x = np.zeros((1, n))
#     return np.concatenate((np.concatenate((hessian_x, hessian_xlambda), axis=1), np.concatenate((hessian_lambda_x, hessian_lambda), axis=1)))

# a = 1
# b = 1
# x = np.array([2,0])
# lamda = 0.5
# hessian = hessian_DL(x, lamda = 0)
# print(hessian)

# rank = np.linalg.matrix_rank(hessian)
# if rank == hessian.shape[1]:
#     print("Matrix is invertible.")
# else:
#     print("Matrix is not invertible.")

# %%
# import autograd.numpy as np
# from autograd import jacobian, hessian

# def hessian_DL(x, lamda, r, a=1, b=1):
#     n = len(x)
#     DL = lambda x: gradient_DL(x, lamda, r, a, b)
#     return hessian(DL)(x)

# x = np.array([1, 2, 3,4])
# lamda = 4
# hessian = hessian_DL(x, lamda,r)
# print(hessian)

# %% [markdown]
# ![image.png](attachment:image.png)
# The search direction s^k is then calculated as the solution to the linear system D^2L(y^k)s^k = DL(y^k), which is obtained by multiplying the inverse of the Hessian by the gradient. The resulting search direction is returned as output. Note that the output will depend on the implementation of the hessian_DL and gradient_DL functions and may vary each time the code is run.

# %%
def search_direction(y_k, lamda = 0.5, r = 2, a=1 , b=1):
    n = len(y_k)
    DL = lagrangian_gradient_func(y_k, lamda, r, a, b)
    D2L = lagrangian_hessian_func(y_k, lamda, r, a, b)
    s_k = np.linalg.solve(D2L, - DL)
    return s_k

y = np.array([1, 2])
s = search_direction(y)
print(s)
# Out:
# [-0.71428571 -2.85714286]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def newton_nextstep(y, lamda = 0.5, r=2, a = 1, b = 1, alpha=1.0):
    s = search_direction(y, lamda = 0.5, r = 2, a=1 , b=1)
    y_new = y + alpha * s
    return y_new

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def check_convergence(x, lamda = 0.5, r = 2, a = 1, b = 1, epsilon =  1e-6):
    gradient = lagrangian_gradient_func(x,lamda, r,a,b)
    gradient_norm = np.linalg.norm(gradient)
    if gradient_norm < epsilon:
        return True
    else:
        return False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(max_iterations):
    gradient = gradient_func(x)
    hessian = hessian_func(x)
    step = -np.linalg.solve(hessian, gradient)
    x = x + step
    if np.linalg.norm(gradient) < epsilon:
        break

# %%
a = 1
b = 1 


def newtons_method(x0, lamda, r=2, epsilon=1e-6, max_iterations=1000):
    y = np.concatenate((x0, [lamda]))
    x_values = [x0]
    for i in range(max_iterations):
        y = newton_nextstep(y, r)
        x_values.append(y[:-1]) #  [:-1]  exclude the last element of the y array,corresponds to lambda, keeps track of values x at each iteration
        if check_convergence(y, epsilon, r):
            break
    return x_values

#######
def newtons_method(x0, lamda, r=2, epsilon=1e-6, max_iterations=10000):
    y = np.concatenate((x0, [lamda]))
    x_values = [x0]
    for i in range(max_iterations):
        y = newton_nextstep(y, r)
        x_values.append(y[:-1]) #  [:-1]  exclude the last element of the y array,corresponds to lambda, keeps track of values x at each iteration
        if check_convergence(y, epsilon, r):
            break
    return x_values


#make a better newtonds method implication, current one is shit 

def newtons_method_2(x, lamda, r=2, a = 1, b = 1,  epsilon=1e-6, max_iterations=10000):
    x = x0
    for i in range(max_iterations):
        gradient = lagrangian_gradient_func(x, lamda, r , a , b)
        hessian = lagrangian_hessian_func(x, lamda, r , a , b)
        step = np.linalg.solve(hessian, -gradient)
        x = x + step
        if np.linalg.norm(gradient) < epsilon:
            break
    return x




########
x_values = newtons_method_2(np.array([0.0001,0.00001]), lamda = 0, r=2, a = 1, b = 1,  epsilon=1e-6, max_iterations=1000)
print(x_values)
x_values = newtons_method(np.array([0.99,0.99]), lamda = 0, r=2, epsilon=1e-6, max_iterations=1000)
print(x_values)

def rosenbrock(x, a=1, b=1):
    return sum(a * (1 - x[:-1])**2.0 + b * (x[1:] - x[:-1]**2.0)**2.0)
# Out:
# [-2.72214582e+10  7.41007787e+20]
# [array([0.99, 0.99]), array([0.82840579, 0.37438736]), array([1.01055566, 0.89658311]), array([0.83554978, 0.36899919]), array([1.02774866, 0.92524201]), array([0.84722102, 0.37778012]), array([1.01760457, 0.89693046]), array([0.84003365, 0.37185037]), array([1.02483749, 0.9163526 ]), array([0.84509142, 0.37590564]), array([1.01993899, 0.90308029]), array([0.84164186, 0.37309367]), array([1.02335078, 0.91228014]), array([0.84403374, 0.37502302]), array([1.02101528, 0.90596447]), array([0.84239124, 0.37368823]), array([1.02263395, 0.91033257]), array([0.84352719, 0.37460675]), array([1.02152131, 0.90732594]), array([0.84274521, 0.37397222]), array([1.02229057, 0.90940265]), array([0.84328531, 0.37440943]), array([1.02176081, 0.90797157]), array([0.8429131 , 0.37410763]), array([1.02212664, 0.90895936]), array([0.84317001, 0.3743157 ]), array([1.02187449, 0.9082783 ]), array([0.84299287, 0.37417213]), array([1.02204851, 0.90874824]), array([0.8431151 , 0.37427114]), array([1.02192852, 0.90842415]), array([0.84303081, 0.37420283]), array([1.02201131, 0.90864773]), array([0.84308896, 0.37424994]), array([1.02195421, 0.90849352]), array([0.84304885, 0.37421744]), array([1.0219936, 0.9085999]), array([0.84307652, 0.37423986]), array([1.02196643, 0.90852653]), array([0.84305743, 0.3742244 ]), array([1.02198517, 0.90857714]), array([0.8430706 , 0.37423506]), array([1.02197225, 0.90854223]), array([0.84306152, 0.3742277 ]), array([1.02198116, 0.90856631]), array([0.84306778, 0.37423278]), array([1.02197501, 0.9085497 ]), array([0.84306346, 0.37422928]), array([1.02197926, 0.90856116]), array([0.84306644, 0.37423169]), array([1.02197633, 0.90855326]), array([0.84306438, 0.37423003]), array([1.02197835, 0.90855871]), array([0.8430658 , 0.37423118]), array([1.02197696, 0.90855495]), array([0.84306482, 0.37423038]), array([1.02197792, 0.90855754]), array([0.8430655 , 0.37423093]), array([1.02197725, 0.90855575]), array([0.84306503, 0.37423055]), array([1.02197771, 0.90855699]), array([0.84306536, 0.37423081]), array([1.0219774 , 0.90855614]), array([0.84306513, 0.37423064]), array([1.02197761, 0.90855672]), array([0.84306529, 0.37423076]), array([1.02197746, 0.90855632]), array([0.84306518, 0.37423067]), array([1.02197757, 0.9085566 ]), array([0.84306525, 0.37423073]), array([1.0219775, 0.9085564]), array([0.8430652 , 0.37423069]), array([1.02197754, 0.90855654]), array([0.84306524, 0.37423072]), array([1.02197751, 0.90855645]), array([0.84306521, 0.3742307 ]), array([1.02197753, 0.90855651]), array([0.84306523, 0.37423071]), array([1.02197752, 0.90855647]), array([0.84306522, 0.3742307 ]), array([1.02197753, 0.9085565 ]), array([0.84306523, 0.37423071]), array([1.02197752, 0.90855647]), array([0.84306522, 0.37423071]), array([1.02197753, 0.90855649]), array([0.84306523, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197753, 0.90855649]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197753, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.37423071]), array([1.02197752, 0.90855648]), array([0.84306522, 0.3 ...

# %%
a = 1
b = 1 


def newtons_method(x0, lamda, r=2, epsilon=1e-6, max_iterations=1000):
    y = np.concatenate((x0, [lamda]))
    x_values = [x0]
    for i in range(max_iterations):
        y = newton_nextstep(y, r)
        x_values.append(y[:-1]) #  [:-1]  exclude the last element of the y array,corresponds to lambda, keeps track of values x at each iteration
        if check_convergence(y, epsilon, r):
            break
    return x_values

########




x_values = newtons_method(x0= np.array([1,0]), lamda=0, r=2, epsilon=1e-6)

def rosenbrock(x, a=1, b=1):
    return sum(a * (1 - x[:-1])**2.0 + b * (x[1:] - x[:-1]**2.0)**2.0)

# %%
#plotting 
# Plot the contours of the Rosenbrock function
r = 2
# Create a meshgrid for the x and y values
x = np.linspace(-2, 2, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the Rosenbrock function on the meshgrid
Z = np.zeros_like(X)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        Z[i, j] = rosenbrock(np.array([X[i, j], Y[i, j]]))

# Plot the contours of the Rosenbrock function
plt.contour(X, Y, Z, levels=np.logspace(0, 5, 35), cmap='jet')

# Plot the constraint set
theta = np.linspace(0, 2 * np.pi, 100)
x_constraint = np.sqrt(r) * np.cos(theta)
y_constraint = np.sqrt(r) * np.sin(theta)
plt.plot(x_constraint, y_constraint, 'k--')

# Plot the values of x at each iteration
x_values = np.array(x_values)
plt.plot(x_values[:, 0], x_values[:, 1], 'ro-')
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def newton_function(x0, a = 1, b = 1, n, epsilon = 1e-6 ):
    x = 




def newton_method(obj_func, gradient_func, hessian_func, x0, epsilon=1e-6, max_iterations=1000):
    x = x0
    for i in range(max_iterations):
        gradient = gradient_func(x)
        hessian = hessian_func(x)
        step = -np.linalg.solve(hessian, gradient)
        x = x + step
        if np.linalg.norm(gradient) < epsilon:
            break
    return x

# %% [markdown]
# # 1b
# ![image.png](attachment:image.png)
#
# $ g(x) = \sum_{i=1}^{n} x_{i}^{2} - r $
#
#  it's important to note that the optimal solution may not necessarily satisfy the constraint np.sum(x**2) - r = 0, since the constraint is relaxed through the use of the penalty method. The optimal solution will be a trade-off between minimizing the objective function and satisfying the constraint, and the strength of the constraint is controlled by the value of P_k.

# %%
from scipy.optimize import minimize
a = b = r = 10 
n = 10 
P_k = 10
x_0 = 0 

#let g(x) be the constraint np.sum(x**2) - r

#objective function
# def rosenbrock(x,a = 10,b = 10):
#     return sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 )

# def constraint_func(x, r = 10 ):
#     return np.sum(x**2) - r

#we can just define this as 1 function it should be better that way

def penalty_func(x,a = 10,b = 10, r = 10, P_k = 1e12):
    obj_func = sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 ) 
    constraint_func = np.sum(x**2) - r
    return obj_func +  P_k * np.linalg.norm(constraint_func)

x0 = np.zeros(5)

res = minimize(penalty_func, x0, method='BFGS')
x_opt = res.x
print("Optimal solution:", x_opt)
# Out:
# Optimal solution: [0. 0. 0. 0. 0.]

# %%
a = b = r = 10
n = 10
P_k = 1e12
x0 = np.array([0,0])

def obj_func(x, a=10, b=10):
    return sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 )

def constraint_func(x, r=10):
    return np.sum(x**2) - r

def penalty_func(x, a=10, b=10, r=10, P_k=1e12):
    obj_val = obj_func(x, a, b)
    constraint_val = constraint_func(x, r)
    return obj_val + P_k * constraint_val**2

res = minimize(penalty_func, x0, method='L-BFGS-B')
x_opt = res.x
print("Optimal solution:", x_opt)
# Out:
# Optimal solution: [0. 0.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#for P0 = 1 case , remember known global minimum is (1,1)

P0case = penalty_func(x = np.zeros(5),a = 10,b = 10, r = 10, P_k = 1e12)
#then minimise 

x0 = np.zeros(5) # initial guess 
a = b = r = 10
#initial penalty set to 1 
P_k = P_0 = 1  
optimumvals = [x0]

for k in range(12):
    res = minimize(penalty_func, x_opt, method='BFGS', args=(a, b, r, P_k))
    x_opt = res.x
    optimumvals.append(x_opt)
    P_k = 10 * P_k

print(optimumvals)

x_opts = np.array(optimumvals)
plt.plot(x_opts[:, 0], 'o-')
plt.xlabel('Iteration')
plt.ylabel('Optimal Value')
plt.title('Penalty Method for Rosenbrock Function')
plt.show()
# Out:
# [array([0., 0., 0., 0., 0.]), array([1.03458291, 1.08261737, 1.16999325, 1.41310313, 2.09300101]), array([1.03895426, 1.07788483, 1.17229068, 1.4137102 , 2.09425317]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313]), array([1.03895429, 1.07788486, 1.1722907 , 1.41371021, 2.09425313])]

# %%
#try using another initial guess
n = 2
x0s = [np.zeros(n), np.ones(n), -np.ones(n), 0.8 * np.ones(n), 10 * np.ones(n)]
P_0 = 1

for x0 in x0s:
    x_opt = x0
    P_k = P_0
    for k in range(12):
        res = minimize(penalty_func, x_opt, method='BFGS', args=(a, b, r, P_k))
        x_opt = res.x
        P_k = 10 * P_k
    print("Initial guess:", x0)
    print("Optimal solution:", x_opt)
    print("Objective function value:", obj_func(x_opt))
    print()
# Out:
# Initial guess: [0. 0.]
# Optimal solution: [-2.74968809e-09 -5.40642336e-09]
# Objective function value: 10.00000005499376
#
# Initial guess: [1. 1.]
# Optimal solution: [ 4.68622716e-09 -4.67321972e-09]
# Objective function value: 9.999999906275455
#
# Initial guess: [-1. -1.]
# Optimal solution: [-1.12702022e-08 -5.83534157e-09]
# Objective function value: 10.000000225404044
#
# Initial guess: [0.8 0.8]
# Optimal solution: [-5.71916244e-09 -2.84185529e-09]
# Objective function value: 10.00000011438325
#
# Initial guess: [10. 10.]
# Optimal solution: [6.27929077e+33 2.14837812e+67]
# Objective function value: 3.220485570507618e+135

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 2
x0s = [np.zeros(n), np.ones(n), -np.ones(n), 0.8 * np.ones(n), 10 * np.ones(n)]
P_0 = 1
b = 1000 

def penalty_func(x,a = 10,b = 10, r = 10, P_k = 1e12):
    obj_func = sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 ) 
    constraint_func = np.sum(x**2) - r
    return obj_func +  P_k * np.linalg.norm(constraint_func)

    
for x0 in x0s:
    x_opt = x0
    P_k = P_0
    b = 1000 
    for k in range(12):
        res = minimize(penalty_func, x_opt, method='BFGS', args=(a, b, r, P_k))
        x_opt = res.x
        P_k = 10 * P_k
    print("Initial guess:", x0)
    print("Optimal solution:", x_opt)
    print("Objective function value:", obj_func(x_opt))
    print()
# Out:
# Initial guess: [0. 0.]
# Optimal solution: [0.78357727 0.62129434]
# Objective function value: 0.46892102733814717
#
# Initial guess: [1. 1.]
# Optimal solution: [0.78357711 0.62129454]
# Objective function value: 0.4689217912172746
#
# Initial guess: [-1. -1.]
# Optimal solution: [0.78357727 0.62129434]
# Objective function value: 0.4689210058484387
#
# Initial guess: [0.8 0.8]
# Optimal solution: [0.78357727 0.62129434]
# Objective function value: 0.4689210123273076
#
# Initial guess: [10. 10.]
# Optimal solution: [0.78357727 0.62129434]
# Objective function value: 0.46892101377215156

# %%
n = 2
x0s = [np.zeros(n), np.ones(n), -np.ones(n), 0.8 * np.ones(n), 10 * np.ones(n)]
P_0 = 1
b = 10

def penalty_func(x,a = 10,b = 10, r = 1, P_k = 1e12):
    obj_func = sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 ) 
    constraint_func = np.sum(x**2) - r
    return obj_func +  P_k * np.linalg.norm(constraint_func)

    
for x0 in x0s:
    x_opt = x0
    P_k = P_0
    r = 1
    b=10
    for k in range(12):
        res = minimize(penalty_func, x_opt, method='BFGS', args=(a, b, r, P_k))
        x_opt = res.x
        P_k = 10 * P_k
    print("Initial guess:", x0)
    print("Optimal solution:", x_opt)
    print("Objective function value:", obj_func(x_opt))
    print()
# Out:
# Initial guess: [0. 0.]
# Optimal solution: [0.8022816  0.59694575]
# Objective function value: 0.4127439075820393
#
# Initial guess: [1. 1.]
# Optimal solution: [0.80228165 0.59694567]
# Objective function value: 0.4127438520878657
#
# Initial guess: [-1. -1.]
# Optimal solution: [0.80228161 0.59694574]
# Objective function value: 0.4127439035110591
#
# Initial guess: [0.8 0.8]
# Optimal solution: [0.80228163 0.5969457 ]
# Objective function value: 0.4127438699778425
#
# Initial guess: [10. 10.]
# Optimal solution: [0.80228162 0.59694573]
# Objective function value: 0.41274389381294296

# %% [markdown]
# # 1c
# ![image.png](attachment:image.png)

# %%
lamda = 10 
def augmented_lagrangian(x,a = 10,b = 10, r = 10, P_k = 1e12, lamda = 10 ):
    obj_func = sum( a*(1-x[:-1])**2.0 + b*(x[1:]-x[:-1]**2.0)**2.0 ) 
    constraint_func = np.sum(x**2) - r

    return obj_func +  P_k * np.linalg.norm(constraint_func) + lamda * constraint_func
